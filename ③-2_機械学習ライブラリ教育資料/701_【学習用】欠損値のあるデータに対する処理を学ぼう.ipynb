# %% [markdown]
# # 欠損値のあるデータに対する処理を学ぼう

# %% [markdown]
# ## データの情報を確認しよう

# %% [markdown]
# ## 欠損値のある行を削除しよう

# %% [markdown]
# ## 欠損値を平均値で補完しよう

# %% [markdown]
# # Google ColaboratoryにGoogleドライブをつなごう

# %% [markdown]
# ## Googleドライブのマウント

# %% [markdown]
# # 外れ値のあるセンサーデータに対する処理を学ぼう

# %% [markdown]
# ## ライブラリとデータのインポート

# %% [markdown]
# ##  データを可視化しよう

# %%
# ビジュアライズ

# %%
# 列ごとに別グラフとして表示

# %% [markdown]
# ## Hampel識別子で外れ値を除去しよう

# %% [markdown]
# ### Hampel識別子を関数化

# %%
# hampelフィルター

# %% [markdown]
# ### 汎用的な関数に変更

# %%
# hampelフィルター

# %% [markdown]
# ### データ処理
